# %% [markdown]
# csv 파일에서 특정 문자를 가진 행만 뽑아내는 코드

# %%
# # 구글 드라이브에서 csv 파일을 읽어오기 위해 gauth 인증을 합니다.
# !pip install -U -q PyDrive
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials
# # Authenticate and create the PyDrive client.
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# %%
# url ='https://drive.google.com/file/d/106EvNN-WgqRUoogtOwsRZCZ-RG6ZP4b4/view?usp=sharing'
# id = url.split('=')[1]
# print(id)

# %%
# %ls #파일보기 명령어
# Out:
# drive/  petitions_b.csv  sample_data/

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype # 그래프의 값을 정렬해서 보기위해
import numpy as np

# %%
petitions = pd.read_csv('/content/petitions_b.csv', index_col=0, \
                        parse_dates=['sday', 'eday'])
# 데이터의 크기가 어느정도인지 본다.
petitions.shape
# Out:
# (2741, 9)

# %%
# head 출력
petitions.head()
# Out:
#        progress                                    title  ...       eday proponent
# number                                                    ...
# 586500     청원종료     대구경북 잠재적 확진자취급하는 타지역 병원의 진료거부를 막아주세요  ... 2020-04-08     naver
# 586505     청원종료  신천지 압수수색 시간끌며 코로나 확산 방조한 윤석열 검찰총장 해임 청원  ... 2020-04-08   twitter
# 586511     청원종료         요양병원의 의료사고 , 저희 할아버지의 억울함을 풀어주세요  ... 2020-04-09  facebook
# 586514     청원종료                                  약안주는 약국  ... 2020-04-09     naver
# 586515     청원종료       마스크 5부제  시행시  미성년자 동행 조건은 철회해 주세요!  ... 2020-04-09     naver
#
# [5 rows x 9 columns]

# %%
petitions_b = petitions.loc[petitions['contents'].str.contains('인과성', na=False)]

# %%
petitions_b.head()
# Out:
#        progress  ... proponent
# number           ...
# 586565     청원종료  ...     kakao
# 586566     청원종료  ...     naver
# 586597     청원종료  ...     naver
# 586664     청원종료  ...     naver
# 586745     청원종료  ...     naver
#
# [5 rows x 9 columns]

# %%
petitions_b.shape
# Out:
# (416, 9)

# %%
petitions_b.to_csv('./petitions_c.csv', sep=',', na_rep='NaN')
